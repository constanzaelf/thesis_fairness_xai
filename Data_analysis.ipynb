# %%
import os

# %%
folder_path = '/home/constanza/tfg/TFG/thesis/segmentations/fn_explanations'
images = []
for image in os.listdir(folder_path):
    images.append(image)
    #break

# %%
print(len(images))
# Out:
# 1951

# %%
heavy_mk = 0
male = 0
female = 0
shadow_count = 0
Arched_Eyebrows_count = 0
Attractive_count = 0
Bags_Under_Eyes_count = 0
Bald_count = 0
Bangs_count = 0
Big_Lips_count = 0
Big_Nose_count = 0
Black_Hair_count = 0
Blond_Hair_count = 0
Blurry_count = 0
Brown_Hair_count = 0
Bushy_Eyebrows_count = 0
Chubby_count = 0
Double_Chin_count = 0
Eyeglasses_count = 0
Goatee_count = 0
Gray_Hair_count = 0
High_Cheekbones_count = 0
Mouth_Slightly_Open_count = 0
Mustache_count = 0
Narrow_Eyes_count = 0
No_Beard_count = 0
Oval_Face_count = 0
Pale_Skin_count = 0
Pointy_Nose_count = 0
Receding_Hairline_count = 0
Rosy_Cheeks_count = 0
Sideburns_count = 0
Smiling_count = 0
Straight_Hair_count = 0
Wavy_Hair_count = 0
Wearing_Earrings_count = 0
Wearing_Hat_count = 0
Wearing_Lipstick_count = 0
Wearing_Necklace_count = 0
Wearing_Necktie_count = 0
Young_count = 0

with open("list_attr_celeba.txt", "r") as file:
    # Leer cada línea del archivo
    next(file)
    next(file)
    for line in file:
        # Dividir la línea en elementos separados por espacios
        elements = line.split()
                
        # Verificar si el primer elemento (nombre de archivo) está en la lista de imágenes
        if elements[0] in images:
            # Obtener los valores de las características
            shadow = int(elements[1])
            Arched_Eyebrows = int(elements[2])
            Attractive = int(elements[3])
            Bags_Under_Eyes = int(elements[4])
            Bald = int(elements[5])
            Bangs = int(elements[6])
            Big_Lips = int(elements[7])
            Big_Nose = int(elements[8])
            Black_Hair = int(elements[9])
            Blond_Hair = int(elements[10])
            Blurry = int(elements[11])
            Brown_Hair = int(elements[12])
            Bushy_Eyebrows = int(elements[13])
            Chubby = int(elements[14])
            Double_Chin = int(elements[15])
            Eyeglasses = int(elements[16])
            Goatee = int(elements[17])
            Gray_Hair = int(elements[18])
            Heavy_Makeup = int(elements[19])
            High_Cheekbones = int(elements[20])
            Male = int(elements[21])
            Mouth_Slightly_Open = int(elements[22])
            Mustache = int(elements[23])
            Narrow_Eyes = int(elements[24])
            No_Beard = int(elements[25])
            Oval_Face = int(elements[26])
            Pale_Skin = int(elements[27])
            Pointy_Nose = int(elements[28])
            Receding_Hairline = int(elements[29])
            Rosy_Cheeks = int(elements[30])
            Sideburns = int(elements[31])
            Smiling = int(elements[32])
            Straight_Hair = int(elements[33])
            Wavy_Hair = int(elements[34])
            Wearing_Earrings = int(elements[35])
            Wearing_Hat = int(elements[36])
            Wearing_Lipstick = int(elements[37])
            Wearing_Necklace = int(elements[38])
            Wearing_Necktie = int(elements[39])
            Young = int(elements[40])

            # Contar las características específicas
            if Heavy_Makeup == 1:
                heavy_mk += 1
            if Male == 1:
                male += 1
            if Male == -1:
                female += 1
                
            # Añadir las variables para el conteo de cada característica
            if shadow == 1:
                shadow_count += 1  
            if Arched_Eyebrows == 1:
                Arched_Eyebrows_count += 1
            if Attractive == 1:
                Attractive_count += 1
            if Bags_Under_Eyes == 1:
                Bags_Under_Eyes_count += 1
            if Bald == 1:
                Bald_count += 1
            if Bangs == 1:
                Bangs_count += 1
            if Big_Lips == 1:
                Big_Lips_count += 1
            if Big_Nose == 1:
                Big_Nose_count += 1
            if Black_Hair == 1:
                Black_Hair_count += 1
            if Blond_Hair == 1:
                Blond_Hair_count += 1
            if Blurry == 1:
                Blurry_count += 1
            if Brown_Hair == 1:
                Brown_Hair_count += 1
            if Bushy_Eyebrows == 1:
                Bushy_Eyebrows_count += 1
            if Chubby == 1:
                Chubby_count += 1
            if Double_Chin == 1:
                Double_Chin_count += 1
            if Eyeglasses == 1:
                Eyeglasses_count += 1
            if Goatee == 1:
                Goatee_count += 1
            if Gray_Hair == 1:
                Gray_Hair_count += 1
            if High_Cheekbones == 1:
                High_Cheekbones_count += 1
            if Mouth_Slightly_Open == 1:
                Mouth_Slightly_Open_count += 1
            if Mustache == 1:
                Mustache_count += 1
            if Narrow_Eyes == 1:
                Narrow_Eyes_count += 1
            if No_Beard == 1:
                No_Beard_count += 1
            if Oval_Face == 1:
                Oval_Face_count += 1
            if Pale_Skin == 1:
                Pale_Skin_count += 1
            if Pointy_Nose == 1:
                Pointy_Nose_count += 1
            if Receding_Hairline == 1:
                Receding_Hairline_count += 1
            if Rosy_Cheeks == 1:
                Rosy_Cheeks_count += 1
            if Sideburns == 1:
                Sideburns_count += 1
            if Smiling == 1:
                Smiling_count += 1
            if Straight_Hair == 1:
                Straight_Hair_count += 1
            if Wavy_Hair == 1:
                Wavy_Hair_count += 1
            if Wearing_Earrings == 1:
                Wearing_Earrings_count += 1
            if Wearing_Hat == 1:
                Wearing_Hat_count += 1
            if Wearing_Lipstick == 1:
                Wearing_Lipstick_count += 1
            if Wearing_Necklace == 1:
                Wearing_Necklace_count += 1
            if Wearing_Necktie == 1:
                Wearing_Necktie_count += 1
            if Young == 1:
                Young_count += 1


# y así sucesivamente para el resto de características...

# %%
print("Total heavy makeup percentage: ",heavy_mk/len(images))
print("Total number of female: ", female/len(images))
print("Total number of male: ", male/len(images))
print("Percentage of female with makeup:", heavy_mk/female)
print("5 o'clock shadow:", shadow_count/len(images))
print("Arched eyebrows: ", Arched_Eyebrows_count/len(images))
print("Bag under eyes:", Bags_Under_Eyes_count/len(images))
print("Bald:", Bald_count/len(images))
print("Bangs:", Bangs_count/len(images))
print("Big lips :", Big_Lips_count/len(images))
print("Big nise:", Big_Nose_count/len(images))
print("Black hair:", Black_Hair_count/len(images))
print("Blond hair:", Blond_Hair_count/len(images))
print("Blurry images:", Blurry_count/len(images))
print("Brown hair:", Brown_Hair_count/len(images))
print("Bushy eyebrows: ", Bushy_Eyebrows_count/len(images))
print("Chubby persons:", Chubby_count/len(images))
print("Double chin:", Double_Chin_count/len(images))
print("Eyeglasses:", Eyeglasses_count/len(images))
print("Goatee:", Goatee_count/len(images))
print("Gray hair:", Gray_Hair_count/len(images))
print("High cheeckbones:", High_Cheekbones_count/len(images))
print("Opened mouth:", Mouth_Slightly_Open_count/len(images))
print("Mustache: ", Mustache_count/len(images))
print("Narrow eyes:", Narrow_Eyes_count/len(images))
print("No Beard:", No_Beard_count/len(images))
print("Oval face:", Oval_Face_count/len(images))
print("Pale skin:", Pale_Skin_count/len(images))
print("Pointy nose:", Pointy_Nose_count/len(images))
print("Receding hairline:", Receding_Hairline_count/len(images))
print("Rossy cheeks:", Rosy_Cheeks_count/len(images))
print("Side burns:", Sideburns_count/len(images))
print("Smiling:", Smiling_count/len(images))
print("Straight hair:", Straight_Hair_count/len(images))
print("Wavy hair:", Wavy_Hair_count/len(images))
print("Wearing earrings:", Wearing_Earrings_count/len(images))
print("Wearing hat:", Wearing_Hat_count/len(images))
print("wearing lipstick:", Wearing_Lipstick_count/len(images))
print("wearing necklace:", Wearing_Necklace_count/len(images))
print("Wearing necktie :", Wearing_Necktie_count/len(images))
print("young:", Young_count/len(images))
# Out:
# Total heavy makeup percentage:  0.47104049205535625
# Total number of female:  0.6986160943106099
# Total number of male:  0.30138390568939005
# Percentage of female with makeup: 0.6742479823917829
# 5 o'clock shadow: 0.12403895438236802
# Arched eyebrows:  0.33470015376729884
# Bag under eyes: 0.17221937467965145
# Bald: 0.0030753459764223477
# Bangs: 0.19887237314197848
# Big lips : 0.35058944131214764
# Big nise: 0.15069195284469503
# Black hair: 0.318298308559713
# Blond hair: 0.14402870322911326
# Blurry images: 0.021527421834956432
# Brown hair: 0.2060481804202973
# Bushy eyebrows:  0.15581752947206562
# Chubby persons: 0.005125576627370579
# Double chin: 0.005638134290107637
# Eyeglasses: 0.013839056893900564
# Goatee: 0.035366478728856995
# Gray hair: 0.0025627883136852894
# High cheeckbones: 0.451050743208611
# Opened mouth: 0.43567401332649924
# Mustache:  0.021527421834956432
# Narrow eyes: 0.12865197334700154
# No Beard: 0.8718605843157355
# Oval face: 0.2706304459251666
# ...

# %%
folder_path = '/home/constanza/tfg/TFG/thesis/segmentations/fp_explanations'
images_fp = []
for image in os.listdir(folder_path):
    images_fp.append(image)
    #break
print(len(images_fp))
# Out:
# 200

# %%
heavy_mk = 0
male = 0
female = 0
shadow_count = 0
Arched_Eyebrows_count = 0
Attractive_count = 0
Bags_Under_Eyes_count = 0
Bald_count = 0
Bangs_count = 0
Big_Lips_count = 0
Big_Nose_count = 0
Black_Hair_count = 0
Blond_Hair_count = 0
Blurry_count = 0
Brown_Hair_count = 0
Bushy_Eyebrows_count = 0
Chubby_count = 0
Double_Chin_count = 0
Eyeglasses_count = 0
Goatee_count = 0
Gray_Hair_count = 0
High_Cheekbones_count = 0
Mouth_Slightly_Open_count = 0
Mustache_count = 0
Narrow_Eyes_count = 0
No_Beard_count = 0
Oval_Face_count = 0
Pale_Skin_count = 0
Pointy_Nose_count = 0
Receding_Hairline_count = 0
Rosy_Cheeks_count = 0
Sideburns_count = 0
Smiling_count = 0
Straight_Hair_count = 0
Wavy_Hair_count = 0
Wearing_Earrings_count = 0
Wearing_Hat_count = 0
Wearing_Lipstick_count = 0
Wearing_Necklace_count = 0
Wearing_Necktie_count = 0
Young_count = 0
totmk=0
totnmk=0
with open("list_attr_celeba.txt", "r") as file:
    # Leer cada línea del archivo
    for line in file:
        # Dividir la línea en elementos separados por espacios
        elements = line.split()
      
        # Verificar si el primer elemento (nombre de archivo) está en la lista de imágenes
        if elements[0] in images_fp:
            # Obtener los valores de las características
            shadow = int(elements[1])
            Arched_Eyebrows = int(elements[2])
            Attractive = int(elements[3])
            Bags_Under_Eyes = int(elements[4])
            Bald = int(elements[5])
            Bangs = int(elements[6])
            Big_Lips = int(elements[7])
            Big_Nose = int(elements[8])
            Black_Hair = int(elements[9])
            Blond_Hair = int(elements[10])
            Blurry = int(elements[11])
            Brown_Hair = int(elements[12])
            Bushy_Eyebrows = int(elements[13])
            Chubby = int(elements[14])
            Double_Chin = int(elements[15])
            Eyeglasses = int(elements[16])
            Goatee = int(elements[17])
            Gray_Hair = int(elements[18])
            Heavy_Makeup = int(elements[19])
            High_Cheekbones = int(elements[20])
            Male = int(elements[21])
            Mouth_Slightly_Open = int(elements[22])
            Mustache = int(elements[23])
            Narrow_Eyes = int(elements[24])
            No_Beard = int(elements[25])
            Oval_Face = int(elements[26])
            Pale_Skin = int(elements[27])
            Pointy_Nose = int(elements[28])
            Receding_Hairline = int(elements[29])
            Rosy_Cheeks = int(elements[30])
            Sideburns = int(elements[31])
            Smiling = int(elements[32])
            Straight_Hair = int(elements[33])
            Wavy_Hair = int(elements[34])
            Wearing_Earrings = int(elements[35])
            Wearing_Hat = int(elements[36])
            Wearing_Lipstick = int(elements[37])
            Wearing_Necklace = int(elements[38])
            Wearing_Necktie = int(elements[39])
            Young = int(elements[40])

            # Contar las características específicas
            if Heavy_Makeup == 1:
                heavy_mk += 1
            if Male == 1:
                male += 1
            if Male == -1:
                female += 1
                
            # Añadir las variables para el conteo de cada característica
            if shadow == 1:
                shadow_count += 1  
            if Arched_Eyebrows == 1:
                Arched_Eyebrows_count += 1
            if Attractive == 1:
                Attractive_count += 1
            if Bags_Under_Eyes == 1:
                Bags_Under_Eyes_count += 1
            if Bald == 1:
                Bald_count += 1
            if Bangs == 1:
                Bangs_count += 1
            if Big_Lips == 1:
                Big_Lips_count += 1
            if Big_Nose == 1:
                Big_Nose_count += 1
            if Black_Hair == 1:
                Black_Hair_count += 1
            if Blond_Hair == 1:
                Blond_Hair_count += 1
            if Blurry == 1:
                Blurry_count += 1
            if Brown_Hair == 1:
                Brown_Hair_count += 1
            if Bushy_Eyebrows == 1:
                Bushy_Eyebrows_count += 1
            if Chubby == 1:
                Chubby_count += 1
            if Double_Chin == 1:
                Double_Chin_count += 1
            if Eyeglasses == 1:
                Eyeglasses_count += 1
            if Goatee == 1:
                Goatee_count += 1
            if Gray_Hair == 1:
                Gray_Hair_count += 1
            if High_Cheekbones == 1:
                High_Cheekbones_count += 1
            if Mouth_Slightly_Open == 1:
                Mouth_Slightly_Open_count += 1
            if Mustache == 1:
                Mustache_count += 1
            if Narrow_Eyes == 1:
                Narrow_Eyes_count += 1
            if No_Beard == 1:
                No_Beard_count += 1
            if Oval_Face == 1:
                Oval_Face_count += 1
            if Pale_Skin == 1:
                Pale_Skin_count += 1
            if Pointy_Nose == 1:
                Pointy_Nose_count += 1
            if Receding_Hairline == 1:
                Receding_Hairline_count += 1
            if Rosy_Cheeks == 1:
                Rosy_Cheeks_count += 1
            if Sideburns == 1:
                Sideburns_count += 1
            if Smiling == 1:
                Smiling_count += 1
            if Straight_Hair == 1:
                Straight_Hair_count += 1
            if Wavy_Hair == 1:
                Wavy_Hair_count += 1
            if Wearing_Earrings == 1:
                Wearing_Earrings_count += 1
            if Wearing_Hat == 1:
                Wearing_Hat_count += 1
            if Wearing_Lipstick == 1:
                Wearing_Lipstick_count += 1
            if Wearing_Necklace == 1:
                Wearing_Necklace_count += 1
            if Wearing_Necktie == 1:
                Wearing_Necktie_count += 1
            if Young == 1:
                Young_count += 1

# %%
print("Total heavy makeup percentage: ",heavy_mk/len(images_fp))
print("Total number of female: ", female/len(images_fp))
print("Total number of male: ", male/len(images_fp))
print("Percentage of female with makeup:", heavy_mk/female)
print("5 o'clock shadow:", shadow_count/len(images_fp))
print("Arched eyebrows: ", Arched_Eyebrows_count/len(images_fp))
print("Bag under eyes:", Bags_Under_Eyes_count/len(images_fp))
print("Bald:", Bald_count/len(images_fp))
print("Bangs:", Bangs_count/len(images_fp))
print("Big lips :", Big_Lips_count/len(images_fp))
print("Big nise:", Big_Nose_count/len(images_fp))
print("Black hair:", Black_Hair_count/len(images_fp))
print("Blond hair:", Blond_Hair_count/len(images_fp))
print("Blurry images:", Blurry_count/len(images_fp))
print("Brown hair:", Brown_Hair_count/len(images_fp))
print("Bushy eyebrows: ", Bushy_Eyebrows_count/len(images_fp))
print("Chubby persons:", Chubby_count/len(images_fp))
print("Double chin:", Double_Chin_count/len(images_fp))
print("Eyeglasses:", Eyeglasses_count/len(images_fp))
print("Goatee:", Goatee_count/len(images_fp))
print("Gray hair:", Gray_Hair_count/len(images_fp))
print("High cheeckbones:", High_Cheekbones_count/len(images_fp))
print("Opened mouth:", Mouth_Slightly_Open_count/len(images_fp))
print("Mustache: ", Mustache_count/len(images_fp))
print("Narrow eyes:", Narrow_Eyes_count/len(images_fp))
print("No Beard:", No_Beard_count/len(images_fp))
print("Oval face:", Oval_Face_count/len(images_fp))
print("Pale skin:", Pale_Skin_count/len(images_fp))
print("Pointy nose:", Pointy_Nose_count/len(images_fp))
print("Receding hairline:", Receding_Hairline_count/len(images_fp))
print("Rossy cheeks:", Rosy_Cheeks_count/len(images_fp))
print("Side burns:", Sideburns_count/len(images_fp))
print("Smiling:", Smiling_count/len(images_fp))
print("Straight hair:", Straight_Hair_count/len(images_fp))
print("Wavy hair:", Wavy_Hair_count/len(images_fp))
print("Wearing earrings:", Wearing_Earrings_count/len(images_fp))
print("Wearing hat:", Wearing_Hat_count/len(images_fp))
print("wearing lipstick:", Wearing_Lipstick_count/len(images_fp))
print("wearing necklace:", Wearing_Necklace_count/len(images_fp))
print("Wearing necktie :", Wearing_Necktie_count/len(images_fp))
print("young:", Young_count/len(images_fp))
# Out:
# Total heavy makeup percentage:  0.61
# Total number of female:  0.78
# Total number of male:  0.22
# Percentage of female with makeup: 0.782051282051282
# 5 o'clock shadow: 0.115
# Arched eyebrows:  0.34
# Bag under eyes: 0.155
# Bald: 0.0
# Bangs: 0.185
# Big lips : 0.46
# Big nise: 0.26
# Black hair: 0.35
# Blond hair: 0.155
# Blurry images: 0.02
# Brown hair: 0.205
# Bushy eyebrows:  0.125
# Chubby persons: 0.005
# Double chin: 0.02
# Eyeglasses: 0.0
# Goatee: 0.03
# Gray hair: 0.015
# High cheeckbones: 0.62
# Opened mouth: 0.58
# Mustache:  0.015
# Narrow eyes: 0.225
# No Beard: 0.885
# Oval face: 0.26
# Pale skin: 0.01
# Pointy nose: 0.285
# Receding hairline: 0.075
# Rossy cheeks: 0.07
# Side burns: 0.025
# Smiling: 0.655
# Straight hair: 0.195
# Wavy hair: 0.445
# Wearing earrings: 0.27
# Wearing hat: 0.02
# wearing lipstick: 0.735
# wearing necklace: 0.205
# Wearing necktie : 0.035
# young: 0.91
# 0
# 0

# %% [markdown]
# Let's do an overall analysis of the database

# %%
totmk=0
totnmk_f=0
smiling = 0
lipstick =0
high_cb_tot = 0
open_mth=0
tot=0

with open("list_attr_celeba.txt", "r") as file:
    # Leer cada línea del archivo
    next(file)
    next(file)
    for line in file:
        tot+=1
        # Dividir la línea en elementos separados por espacios
        elements = line.split()
        if int(elements[19])==1 and int(elements[21])!=1:
            totmk+=1
        elif int(elements[19])!=1 and int(elements[21])!=1:
            totnmk_f+=1
        if int(elements[32])==1:
            smiling+=1
        if int(elements[37])==1 and int(elements[21])!=1:
            lipstick+=1
        if int(elements[20])==1:
            high_cb_tot += 1
        if int(elements[22])==1:
            open_mth += 1
        
            

            
print("Total number of Heavy MakeUp females: ",totmk)
print("Total number of NOT Heavy MakeUp females: ",totnmk_f)
fem = totmk+totnmk_f
print("Total number of females: ",fem)
print("Similing people: ", (smiling/tot)*100,"%")
print("Woman with lipstick: ", (lipstick/fem)*100,"%")
print("High cheeckbone people: ", (high_cb_tot/tot)*100,"%")
print("Opened mouth people: ", (open_mth/tot)*100,"%")
# Out:
# Total number of Heavy MakeUp females:  78156
# Total number of NOT Heavy MakeUp females:  40009
# Total number of females:  118165
# Similing people:  48.20803656483991 %
# Woman with lipstick:  80.55854102314561 %
# High cheeckbone people:  45.50318609667372 %
# Opened mouth people:  48.34278550239636 %

# %%
heavy_mk = 0
male = 0
female = 0
shadow_count = 0
Arched_Eyebrows_count = 0
Attractive_count = 0
Bags_Under_Eyes_count = 0
Bald_count = 0
Bangs_count = 0
Big_Lips_count = 0
Big_Nose_count = 0
Black_Hair_count = 0
Blond_Hair_count = 0
Blurry_count = 0
Brown_Hair_count = 0
Bushy_Eyebrows_count = 0
Chubby_count = 0
Double_Chin_count = 0
Eyeglasses_count = 0
Goatee_count = 0
Gray_Hair_count = 0
High_Cheekbones_count = 0
Mouth_Slightly_Open_count = 0
Mustache_count = 0
Narrow_Eyes_count = 0
No_Beard_count = 0
Oval_Face_count = 0
Pale_Skin_count = 0
Pointy_Nose_count = 0
Receding_Hairline_count = 0
Rosy_Cheeks_count = 0
Sideburns_count = 0
Smiling_count = 0
Straight_Hair_count = 0
Wavy_Hair_count = 0
Wearing_Earrings_count = 0
Wearing_Hat_count = 0
Wearing_Lipstick_count = 0
Wearing_Necklace_count = 0
Wearing_Necktie_count = 0
Young_count = 0
with open("list_attr_celeba.txt", "r") as file:
    # Leer cada línea del archivo
    next(file)
    next(file)
    for line in file:
        # Dividir la línea en elementos separados por espacios
        elements = line.split()
        shadow = int(elements[1])
        Arched_Eyebrows = int(elements[2])
        Attractive = int(elements[3])
        Bags_Under_Eyes = int(elements[4])
        Bald = int(elements[5])
        Bangs = int(elements[6])
        Big_Lips = int(elements[7])
        Big_Nose = int(elements[8])
        Black_Hair = int(elements[9])
        Blond_Hair = int(elements[10])
        Blurry = int(elements[11])
        Brown_Hair = int(elements[12])
        Bushy_Eyebrows = int(elements[13])
        Chubby = int(elements[14])
        Double_Chin = int(elements[15])
        Eyeglasses = int(elements[16])
        Goatee = int(elements[17])
        Gray_Hair = int(elements[18])
        Heavy_Makeup = int(elements[19])
        High_Cheekbones = int(elements[20])
        Male = int(elements[21])
        Mouth_Slightly_Open = int(elements[22])
        Mustache = int(elements[23])
        Narrow_Eyes = int(elements[24])
        No_Beard = int(elements[25])
        Oval_Face = int(elements[26])
        Pale_Skin = int(elements[27])
        Pointy_Nose = int(elements[28])
        Receding_Hairline = int(elements[29])
        Rosy_Cheeks = int(elements[30])
        Sideburns = int(elements[31])
        Smiling = int(elements[32])
        Straight_Hair = int(elements[33])
        Wavy_Hair = int(elements[34])
        Wearing_Earrings = int(elements[35])
        Wearing_Hat = int(elements[36])
        Wearing_Lipstick = int(elements[37])
        Wearing_Necklace = int(elements[38])
        Wearing_Necktie = int(elements[39])
        Young = int(elements[40])
        if Heavy_Makeup == 1 and Male == -1 :
            heavy_mk += 1
        if Male == 1:
            male += 1
        if Male == -1:
            female += 1    
        # Añadir las variables para el conteo de cada característica
        if shadow == 1:
            shadow_count += 1  
        if Arched_Eyebrows == 1:
            Arched_Eyebrows_count += 1
        if Attractive == 1:
            Attractive_count += 1
        if Bags_Under_Eyes == 1:
            Bags_Under_Eyes_count += 1
        if Bald == 1:
            Bald_count += 1
        if Bangs == 1:
            Bangs_count += 1
        if Big_Lips == 1:
            Big_Lips_count += 1
        if Big_Nose == 1 and Male==-1:
            Big_Nose_count += 1
        if Black_Hair == 1:
            Black_Hair_count += 1
        if Blond_Hair == 1:
            Blond_Hair_count += 1
        if Blurry == 1: 
            Blurry_count += 1
        if Brown_Hair == 1:
            Brown_Hair_count += 1
        if Bushy_Eyebrows == 1:
            Bushy_Eyebrows_count += 1
        if Chubby == 1:
            Chubby_count += 1
        if Double_Chin == 1:
            Double_Chin_count += 1
        if Eyeglasses == 1:
            Eyeglasses_count += 1
        if Goatee == 1:
            Goatee_count += 1
        if Gray_Hair == 1:
            Gray_Hair_count += 1
        if High_Cheekbones == 1:
            High_Cheekbones_count += 1
        if Mouth_Slightly_Open == 1:
            Mouth_Slightly_Open_count += 1
        if Mustache == 1:
            Mustache_count += 1
        if Narrow_Eyes == 1:
            Narrow_Eyes_count += 1
        if No_Beard == 1:
            No_Beard_count += 1
        if Oval_Face == 1:
            Oval_Face_count += 1
        if Pale_Skin == 1:
            Pale_Skin_count += 1
        if Pointy_Nose == 1 and Male==1:
            Pointy_Nose_count += 1
        if Receding_Hairline == 1:
            Receding_Hairline_count += 1
        if Rosy_Cheeks == 1:
            Rosy_Cheeks_count += 1
        if Sideburns == 1:
            Sideburns_count += 1
        if Smiling == 1 and Male!=1:
            Smiling_count += 1
        if Straight_Hair == 1:
            Straight_Hair_count += 1
        if Wavy_Hair == 1:
            Wavy_Hair_count += 1
        if Wearing_Earrings == 1:
            Wearing_Earrings_count += 1
        if Wearing_Hat == 1:
            Wearing_Hat_count += 1
        if Wearing_Lipstick == 1 and Male!=1:
            Wearing_Lipstick_count += 1
        if Wearing_Necklace == 1:
            Wearing_Necklace_count += 1
        if Wearing_Necktie == 1:
            Wearing_Necktie_count += 1
        if Young == 1:
            Young_count += 1
tot = female + male

# %%
print("Total heavy makeup percentage: ",heavy_mk/female)
print("Total number of female: ", female/tot)
print("Total number of male: ", male/tot)
print("5 o'clock shadow:", shadow_count/tot)
print("Arched eyebrows: ", Arched_Eyebrows_count/tot)
print("Bag under eyes:", Bags_Under_Eyes_count/tot)
print("Bald:", Bald_count/tot)
print("Bangs:", Bangs_count/tot)
print("Big lips :", Big_Lips_count/tot)
print("Big nose:", Big_Nose_count/female)
print("Black hair:", Black_Hair_count/tot)
print("Blond hair:", Blond_Hair_count/tot)
print("Blurry images:", Blurry_count/tot)
print("Brown hair:", Brown_Hair_count/tot)
print("Bushy eyebrows: ", Bushy_Eyebrows_count/tot)
print("Chubby persons:", Chubby_count/tot)
print("Double chin:", Double_Chin_count/tot)
print("Eyeglasses:", Eyeglasses_count/tot)
print("Goatee:", Goatee_count/tot)
print("Gray hair:", Gray_Hair_count/tot)
print("High cheeckbones:", High_Cheekbones_count/tot)
print("Opened mouth:", Mouth_Slightly_Open_count/tot)
print("Mustache: ", Mustache_count/tot)
print("Narrow eyes:", Narrow_Eyes_count/tot)
print("No Beard:", No_Beard_count/tot)
print("Oval face:", Oval_Face_count/tot)
print("Pale skin:", Pale_Skin_count/tot)
print("Pointy nose:", Pointy_Nose_count/male)
print("Receding hairline:", Receding_Hairline_count/tot)
print("Rossy cheeks:", Rosy_Cheeks_count/tot)
print("Side burns:", Sideburns_count/tot)
print("Smiling:", Smiling_count/tot)
print("Straight hair:", Straight_Hair_count/tot)
print("Wavy hair:", Wavy_Hair_count/tot)
print("Wearing earrings:", Wearing_Earrings_count/tot)
print("Wearing hat:", Wearing_Hat_count/tot)
print("wearing lipstick:", Wearing_Lipstick_count/female)
print("wearing necklace:", Wearing_Necklace_count/tot)
print("Wearing necktie :", Wearing_Necktie_count/tot)
print("young:", Young_count/tot)
print(Smiling_count/97669)
# Out:
# Total heavy makeup percentage:  0.6614141243176913
# Total number of female:  0.5832457218446291
# Total number of male:  0.41675427815537097
# 5 o'clock shadow: 0.11113579040370387
# Arched eyebrows:  0.26698058726844653
# Bag under eyes: 0.20457159215988233
# Bald: 0.022443348683853327
# Bangs: 0.15157527924619568
# Big lips : 0.24079585782753124
# Big nose: 0.1022722464350696
# Black hair: 0.23925093411122464
# Blond hair: 0.14799184596172735
# Blurry images: 0.05089857304330229
# Brown hair: 0.2051935103332198
# Bushy eyebrows:  0.14216753290983666
# Chubby persons: 0.05756691790186526
# Double chin: 0.046688285726977925
# Eyeglasses: 0.06511878143524893
# Goatee: 0.06276437692189991
# Gray hair: 0.041949861549168556
# High cheeckbones: 0.45503186096673726
# Opened mouth: 0.48342785502396357
# Mustache:  0.04154512115064734
# Narrow eyes: 0.11514864337928618
# No Beard: 0.8349399552811219
# Oval face: 0.28414256733744986
# Pale skin: 0.04294690496991594
# ...
