# %%
import matplotlib.pyplot as plt

# Datos
data_nose = {
    
    "Before any Alteration": {
        "ΔFP": 0.06884,
        "ΔFN": -0.35,
        "ΔAccuracy": -0.0927,
        "ΔSP": 0.3366,
        "ΔEO": 0.3534,
        "Δauc": -0.01738,
        "All Accuracy": 0.7365,
        "Precision": 0.92,
        "Recall": 0.51212,
        "F1": 0.658
    },
    "Nose alteration 0.3 blend Male": {
        "ΔFP": 0.0642,
        "ΔFN": -0.3591,
        "ΔAccuracy": -0.0929251,
        "ΔSP": 0.33279414,
        "ΔEO": 0.35912907,
        "Δauc": -0.0151889,
        "All Accuracy": 0.7325,
        "Precision": 0.922077,
        "Recall": 0.502,
        "F1": 0.65
    },
    "Nose alteration 0.5 blend Male": {
        "ΔFP": 0.0625,
        "ΔFN": -0.3439,
        "ΔAccuracy": -0.0955158,
        "ΔSP": 0.32761279,
        "ΔEO": 0.34390065,
        "Δauc": -0.012408,
        "All Accuracy": 0.7335,
        "Precision": 0.92081,
        "Recall": 0.50505,
        "F1": 0.6523
    },
    "Nose alteration 0.65 blend Male": {
        "ΔFP": 0.0625,
        "ΔFN": -0.3439,
        "ΔAccuracy": -0.09555,
        "ΔSP": 0.327612,
        "ΔEO": 0.34392,
        "Δauc": -0.0124,
        "All Accuracy": 0.7335,
        "Precision": 0.92081,
        "Recall": 0.50505,
        "F1": 0.6523
    },
    "Nose alteration 0.8 blend Male": {
        "ΔFP": 0.05555,
        "ΔFN": -0.3235,
        "ΔAccuracy": -0.0955158,
        "ΔSP": 0.31725009,
        "ΔEO": 0.32359608,
        "Δauc": -0.0080558,
        "All Accuracy": 0.7335,
        "Precision": 0.9147,
        "Recall": 0.50909,
        "F1": 0.654121
    },
    "Nose Alteration 1 blend Male": {
        "ΔFP": 0.05555,
        "ΔFN": -0.3489,
        "ΔAccuracy": -0.0890391,
        "ΔSP": 0.32372678,
        "ΔEO": 0.34897679,
        "Δauc": -0.0036506,
        "All Accuracy": 0.731,
        "Precision": 0.913919,
        "Recall": 0.50404,
        "F1": 0.6497
    },
    "Nose alteration 0.3 blend": {
        "ΔFP": 0.07574213,
        "ΔFN": -0.3629,
        "ΔAccuracy": -0.0945512,
        "ΔSP": 0.3392982,
        "ΔEO": 0.36290266,
        "Δauc": -0.0188642,
        "All Accuracy": 0.7315,
        "Precision": 0.91407,
        "Recall": 0.50505,
        "F1": 0.65061
    },
    "Nose alteration 0.5 blend": {
        "ΔFP": 0.0831,
        "ΔFN": -0.3527,
        "ΔAccuracy": -0.0971418,
        "ΔSP": 0.34062092,
        "ΔEO": 0.35270568,
        "Δauc": -0.0242397,
        "All Accuracy": 0.7325,
        "Precision": 0.9069,
        "Recall": 0.512121,
        "F1": 0.6546158
    },
    "Nose alteration 0.65 blend": {
        "ΔFP": 0.08549,
        "ΔFN": -0.3426,
        "ΔAccuracy": -0.1044589,
        "ΔSP": 0.33492986,
        "ΔEO": 0.34264279,
        "Δauc": -0.0289386,
        "All Accuracy": 0.728,
        "Precision": 0.9056,
        "Recall": 0.50404,
        "F1": 0.64763
    },
    "Nose alteration 0.8 blend": {
        "ΔFP": 0.07854,
        "ΔFN": -0.3185646,
        "ΔAccuracy": -0.1068979,
        "ΔSP": 0.32212814,
        "ΔEO": 0.31856463,
        "Δauc": -0.0271898,
        "All Accuracy": 0.7265,
        "Precision": 0.89766,
        "Recall": 0.50505,
        "F1": 0.64641
    },
    "Nose alteration 1 blend": {
        "ΔFP": 0.07624,
        "ΔFN": -0.33332,
        "ΔAccuracy": -0.1069253,
        "ΔSP": 0.32047475,
        "ΔEO": 0.33262459,
        "Δauc": -0.0280531,
        "All Accuracy": 0.72,
        "Precision": 0.89667,
        "Recall": 0.490909,
        "F1": 0.63446
    }
}
data_eyes = {
    
    "Eyes alteration 0.3 blend Male": {
    "ΔFP": 0.0642,
    "ΔFN": -0.3638,
    "ΔAccuracy": "c",
    "ΔSP": 0.3343,
    "ΔEO": 0.3638,
    "Δauc": -0.0116,
    "All Accuracy": 0.732,
    "Precision": 0.9219,
    "Recall": 0.5010,
    "F1": 0.6492
    },
    "Eyes alteration 0.5 blend Male": {
        "ΔFP": 0.0659,
        "ΔFN": -0.3740,
        "ΔAccuracy": "c",
        "ΔSP": 0.3382,
        "ΔEO": 0.3741,
        "Δauc": -0.0217,
        "All Accuracy": 0.7315,
        "Precision": 0.9233,
        "Recall": 0.4989,
        "F1": 0.6449
    },
    "Eyes alteration 0.65 blend Male": {
        "ΔFP": 0.0677,
        "ΔFN": -0.3791,
        "ΔAccuracy": "c",
        "ΔSP": 0.3408,
        "ΔEO": 0.3791,
        "Δauc": -0.0216,
        "All Accuracy": 0.7315,
        "Precision": 0.9249,
        "Recall": 0.4979,
        "F1": 0.6474
    },
    "Eyes alteration 0.8 blend Male": {
        "ΔFP": 0.0695,
        "ΔFN": -0.3894,
        "ΔAccuracy": "c",
        "ΔSP": 0.3447,
        "ΔEO": 0.3893,
        "Δauc": -0.0216,
        "All Accuracy": 0.731,
        "Precision": 0.9264,
        "Recall": 0.4959,
        "F1": 0.6460
    },
    
    "Eyes alteration 1 blend Male": {
        "ΔFP": 0.0677,
        "ΔFN": -0.3893,
        "ΔAccuracy": "c",
        "ΔSP": 0.3434,
        "ΔEO": 0.3893,
        "Δauc": -0.0226,
        "All Accuracy": 0.7305,
        "Precision": 0.9246,
        "Recall": 0.4959,
        "F1": 0.6452
    },

    
    "Eyes alteration 0.3 blend": {
        "ΔFP": 0.05735,
        "ΔFN": -0.330921,
        "ΔAccuracy": -0.110591,
        "ΔSP": 0.310003,
        "ΔEO": 0.3309202,
        "Δauc": -0.020124,
        "All Accuracy": 0.72,
        "Precision": 0.92322,
        "Recall": 0.47373,
        "F1": 0.6261
    },
    "Eye alteration 0.5 blend": {
        "ΔFP": 0.0521939,
        "ΔFN": -0.30328,
        "ΔAccuracy": -0.131265,
        "ΔSP": 0.2870382,
        "ΔEO": 0.30329,
        "Δauc": -0.02349,
        "All Accuracy": 0.706,
        "Precision": 0.925847,
        "Recall": 0.4414,
        "F1": 0.5978
    },
    "Eyes alteration 0.8 blend": {
        "ΔFP": 0.0521939,
        "ΔFN": -0.3032899,
        "ΔAccuracy": -0.1730,
        "ΔSP": 0.245507,
        "ΔEO": 0.247989,
        "Δauc": -0.03535,
        "All Accuracy": 0.679,
        "Precision": 0.92647,
        "Recall": 0.3818,
        "F1": 0.54077
    },
    "Eye alteration 1 blend": {
        "ΔFP": 0.04473,
        "ΔFN": -0.206427,
        "ΔAccuracy": -0.1978,
        "ΔSP": 0.216547,
        "ΔEO": 0.20642,
        "Δauc": -0.197836,
        "All Accuracy": 0.6625,
        "Precision": 0.92,
        "Recall": 0.34848,
        "F1": 0.50549
    }}
data_mouth={
    
    "MOUTH alteration 0.3 blend Male": {
        "ΔFP": 0.0677,
        "ΔFN": -0.38958,
        "ΔAccuracy": -0.0877438,
        "ΔSP": 0.34315683,
        "ΔEO": 0.38958593,
        "Δauc": -0.0170869,
        "All Accuracy": 0.7305,
        "Precision": 0.92467,
        "Recall": 0.4959,
        "F1": 0.6456
    },
    "MOUTH alteration 0.5 blend Male": {
        "ΔFP": 0.0712,
        "ΔFN": -0.42511,
        "ΔAccuracy": -0.0812671,
        "ΔSP": 0.35481486,
        "ΔEO": 0.42511892,
        "Δauc": -0.0082324,
        "All Accuracy": 0.728,
        "Precision": 0.927203,
        "Recall": 0.48888,
        "F1": 0.64021
    },
    "MOUTH alteration 0.65 blend Male": {
        "ΔFP": 0.0694,
        "ΔFN": -0.4454,
        "ΔAccuracy": 0.0747904,
        "ΔSP": 0.35870087,
        "ΔEO": 0.44542349,
        "Δauc": 0.00069282,
        "All Accuracy": 0.7255,
        "Precision": 0.9248,
        "Recall": 0.4848,
        "F1": 0.6361
    },
    "MOUTH alteration 0.8 blend Male": {
        "ΔFP": 0.0729,
        "ΔFN": -0.4605,
        "ΔAccuracy": -0.07349,
        "ΔSP": 0.36518,
        "ΔEO": 0.460657,
        "Δauc": 0.0073845,
        "All Accuracy": 0.725,
        "Precision": 0.928,
        "Recall": 0.48181,
        "F1": 0.6343
    },
    "MOUTH alteration 1 blend Male": {
        "ΔFP": 0.07294,
        "ΔFN": -0.47588,
        "ΔAccuracy": -0.0696091,
        "ΔSP": 0.36906357,
        "ΔEO": 0.47588034,
        "Δauc": 0.01401438,
        "All Accuracy": 0.7235,
        "Precision": 0.92759,
        "Recall": 0.47878,
        "F1": 0.6315
    },
    "MOUTH alteration 0.3 blend": {
    "ΔFP": 0.05393,
    "ΔFN": -0.3304,
    "ΔAccuracy": -0.1210771,
    "ΔSP": 0.3000674,
    "ΔEO": 0.33047964,
    "Δauc": -0.0199381,
    "All Accuracy": 0.71,
    "Precision": 0.92887,
    "Recall": 0.44848,
    "F1": 0.6049
    },
    "MOUTH alteration 0.5 blend": {
        "ΔFP": 0.04591,
        "ΔFN": -0.3131,
        "ΔAccuracy": -0.1446817,
        "ΔSP": 0.27351405,
        "ΔEO": 0.31316923,
        "Δauc": -0.013177,
        "All Accuracy": 0.689,
        "Precision": 0.93601,
        "Recall": 0.3989,
        "F1": 0.5594
    },
    "MOUTH alteration 0.65 blend": {
        "ΔFP": 0.02578,
        "ΔFN": -0.2947,
        "ΔAccuracy": -0.1609693,
        "ΔSP": 0.2416199,
        "ΔEO": 0.28818645,
        "Δauc": -0.005501,
        "All Accuracy": 0.6725,
        "Precision": 0.94667,
        "Recall": 0.3558,
        "F1": 0.5201
    },
    "MOUTH alteration 0.8 blend": {
        "ΔFP": 0.024667,
        "ΔFN": -0.25058,
        "ΔAccuracy": -0.19219,
        "ΔSP": 0.2123324,
        "ΔEO": 0.250559,
        "Δauc": -0.0004547,
        "All Accuracy": 0.652,
        "Precision": 0.9509,
        "Recall": 0.3147,
        "F1": 0.4711
    },
    "MOUTH alteration 1 blend": {
        "ΔFP": 0.02,
        "ΔFN": -0.20669,
        "ΔAccuracy": -0.224894,
        "ΔSP": 0.1763906,
        "ΔEO": 0.20669795,
        "Δauc": 0.00078533,
        "All Accuracy": 0.628,
        "Precision": 0.9489,
        "Recall": 0.2626,
        "F1": 0.411
    }

    


}

# %%
delta_SP = [values["ΔSP"] for values in data_nose.values()]
all_accuracy = [values["All Accuracy"] for values in data_nose.values()]

plt.figure(figsize=(18, 12))

for i, txt in enumerate(data_nose.keys()):
    plt.scatter(delta_SP[i], all_accuracy[i], label=txt)

plt.title('ΔSP vs. All Accuracy NOSE')
plt.xlabel('ΔSP')
plt.ylabel('All Accuracy')
plt.grid(True)

plt.legend(loc='lower center', bbox_to_anchor=(0.5, -0.2), ncol=5)
plt.savefig('graph_imageSP.png', bbox_inches='tight')
plt.tight_layout()
plt.show()
plt.savefig("graph_SP_accuracy_nose.jpg")

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

delta_EO = [values["ΔEO"] for values in data_nose.values()]
delta_SP = [values["ΔSP"] for values in data_nose.values()]
all_accuracy = [values["All Accuracy"] for values in data_nose.values()]
labels = list(data_nose.keys())

fig = plt.figure(figsize=(20, 20))
ax = fig.add_subplot(111, projection='3d')

sc = ax.scatter(delta_EO, delta_SP, all_accuracy, c=range(len(delta_EO)), cmap='tab10', s=500)

for i in range(len(delta_EO)):
    ax.plot([delta_EO[i], delta_EO[i]], [delta_SP[i], delta_SP[i]], [0.7, all_accuracy[i]], color='gray', linestyle='--', alpha=0.5)

ax.set_xlabel('ΔEO')
ax.set_ylabel('ΔSP')
ax.set_zlabel('All Accuracy')
ax.set_title('Gráfico 3D: ΔEO vs. ΔSP vs. All Accuracy')
ax.set_zlim(0.7, 0.735)
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=sc.to_rgba(i), markersize=10) for i in range(len(labels))]
ax.legend(handles, labels, loc='center left', bbox_to_anchor=(1.2, 0.8), prop={'size': 25})

plt.savefig('graph_3d_nose.png', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Datos
delta_EO = [values["ΔEO"] for values in data_mouth.values()]
delta_SP = [values["ΔSP"] for values in data_mouth.values()]
all_accuracy = [values["All Accuracy"] for values in data_mouth.values()]
labels = list(data_mouth.keys())

fig = plt.figure(figsize=(20, 20))
ax = fig.add_subplot(111, projection='3d')

sc = ax.scatter(delta_EO, delta_SP, all_accuracy, c=range(len(delta_EO)), cmap='tab10', s=500)
for i in range(len(delta_EO)):
    ax.plot([delta_EO[i], delta_EO[i]], [delta_SP[i], delta_SP[i]], [0.628, all_accuracy[i]], color='gray', linestyle='--', alpha=0.5)

ax.set_xlabel('ΔEO')
ax.set_ylabel('ΔSP')
ax.set_zlabel('All Accuracy')
ax.set_title('3D Graph: ΔEO vs. ΔSP vs. All Accuracy')
ax.set_zlim(0.628, 0.735)
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=sc.to_rgba(i), markersize=10) for i in range(len(labels))]
ax.legend(handles, labels, loc='center left', bbox_to_anchor=(1.2, 0.8),prop={'size': 25})

plt.savefig('graph_3d_mouth.png', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Datos
delta_EO = [values["ΔEO"] for values in data_eyes.values()]
delta_SP = [values["ΔSP"] for values in data_eyes.values()]
all_accuracy = [values["All Accuracy"] for values in data_eyes.values()]
labels = list(data_eyes.keys())

fig = plt.figure(figsize=(20, 20))
ax = fig.add_subplot(111, projection='3d')

sc = ax.scatter(delta_EO, delta_SP, all_accuracy, c=range(len(delta_EO)), cmap='tab10', s=500)
for i in range(len(delta_EO)):
    ax.plot([delta_EO[i], delta_EO[i]], [delta_SP[i], delta_SP[i]], [0.6625, all_accuracy[i]], color='gray', linestyle='--', alpha=0.5)

ax.set_xlabel('ΔEO')
ax.set_ylabel('ΔSP')
ax.set_zlabel('All Accuracy')
ax.set_title('3D Graph: ΔEO vs. ΔSP vs. All Accuracy')
ax.set_zlim(0.6625, 0.735)
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=sc.to_rgba(i), markersize=10) for i in range(len(labels))]
ax.legend(handles, labels, loc='center left', bbox_to_anchor=(1.2, 0.8),prop={'size': 25})

plt.savefig('graph_3d_eyes.png', bbox_inches='tight')
plt.show()

# %%
delta_EO = [values["ΔEO"] for values in data_nose.values()]
all_accuracy = [values["All Accuracy"] for values in data_nose.values()]

plt.figure(figsize=(18, 12))

for i, txt in enumerate(data_nose.keys()):
    plt.scatter(delta_EO[i], all_accuracy[i], label=txt)

plt.title('ΔEO vs. All Accuracy Nose')
plt.xlabel('ΔEO')
plt.ylabel('All Accuracy')
plt.grid(True)

plt.legend(loc='lower center', bbox_to_anchor=(0.5, -0.2), ncol=5)
plt.savefig('graph_imageN.png', bbox_inches='tight')
plt.tight_layout()
plt.show()
plt.savefig("graph_EO_accuracy_nose.jpg")

# %%
data2 = {
  "MOUTH alteration 100% blend & NOSE alteration 100\% blend Male": {
    "ΔFP": 0.014852,
    "ΔFN": -0.20669,
    "ΔAccuracy": -0.2210076,
    "ΔSP": 0.17249463,
    "ΔEO": 0.2066979,
    "Δauc": 0.01160836,
    "All Accuracy": 0.6265,
    "Precision": 0.9386,
    "Recall": 0.2626,
    "F1": 0.4104
  },
  "MOUTH alteration 65% blend Male & NOSE alteration 100% blend Male": {
    "ΔFP": 0.0659,
    "ΔFN": -0.4098,
    "ΔAccuracy": -0.0657231,
    "ΔSP": 0.34704284,
    "ΔEO": 0.4098905,
    "Δauc": 0.01397024,
    "All Accuracy": 0.7272,
    "Precision": 0.922348,
    "Recall": 0.490927,
    "F1": 0.640789
  },
  "MOUTH alteration 80% blend Male & NOSE alteration 80% blend Male": {
    "ΔFP": 0.06772,
    "ΔFN": -0.46065,
    "ΔAccuracy": -0.0696091,
    "ΔSP": 0.36129155,
    "ΔEO": 0.46065192,
    "Δauc": 0.01397024,
    "All Accuracy": 0.72277,
    "Precision": 0.92263,
    "Recall": 0.4808,
    "F1": 0.632206
  },
  "MOUTH alteration 80% blend & NOSE alteration 80% blend Male": {
    "ΔFP": 0.01945,
    "ΔFN": -0.2505,
    "ΔAccuracy": -0.1883083,
    "ΔSP": 0.20844602,
    "ΔEO": 0.25058902,
    "Δauc": 0.00613101,
    "All Accuracy": 0.6498,
    "Precision": 0.9422,
    "Recall": 0.3125,
    "F1": 0.4693
  },
  "NOSE alteration 80% blend & MOUTH alteration 80% blend Male ": {
    "ΔFP": 0.70779,
    "ΔFN": -0.4292,
    "ΔAccuracy": -0.0939993,
    "ΔSP": 0.34503138,
    "ΔEO": 0.42920538,
    "Δauc": -0.0108516,
    "All Accuracy": 0.7077,
    "Precision": 0.909,
    "Recall": 0.4556,
    "F1": 0.607
  },
  "MOUTH alteration 80% blend Male & NOSE alteration 80% blend Male & NOSE alteration 50% blend Female": {
    "ΔFP": 0.9015,
    "ΔFN": -0.4645,
    "ΔAccuracy": -0.0742,
    "ΔSP": 0.3745,
    "ΔEO": 0.4645,
    "Δauc": 0.00576,
    "All Accuracy": 0.7235,
    "Precision": 0.909943,
    "Recall": 0.4899,
    "F1": 0.6369
  },
  "MOUTH alteration 50% blend Male & NOSE alteration 100% blend Male & NOSE alteration 50\% blend Female": {
    "ΔFP": 0.0866766,
    "ΔFN": -0.3675,
    "ΔAccuracy": -0.09930,
    "ΔSP": 0.34734,
    "ΔEO": 0.367578,
    "Δauc": -0.00468,
    "All Accuracy": 0.732,
    "Precision": 0.90974,
    "Recall": 0.509,
    "F1": 0.6528
  },
  "MOUTH alteration 100% blend & NOSE alteration 100% blend": {
    "ΔFP": 0.011994,
    "ΔFN": -0.1900864,
    "ΔAccuracy": -0.2278877,
    "ΔSP": 0.1656266,
    "ΔEO": 0.190086,
    "Δauc": -0.0277607,
    "All Accuracy": 0.6265,
    "Precision": 0.948339,
    "Recall": 0.259559,
    "F1": 0.4076
  },
  "MOUTH alteration 50% blend & NOSE alteration 100% blend Male": {
    "ΔFP": 0.040699,
    "ΔFN": -0.24667,
    "ΔAccuracy": -0.1581453,
    "ΔSP": 0.252963,
    "ΔEO": 0.246671,
    "Δauc": -0.0008027,
    "All Accuracy": 0.694,
    "Precision": 0.9315,
    "Recall": 0.41212,
    "F1": 0.5714
  },
  "MOUTH alteration 50% blend & NOSE alteration 80% blend Male": {
    "ΔFP": 0.0424,
    "ΔFN": -0.2619,
    "ΔAccuracy": 0,
    "ΔSP": 0.2581,
    "ΔEO": 0.2619,
    "Δauc": -0.00447,
    "All Accuracy": 0.693,
    "Precision": 0.9331,
    "Recall": 0.4090,
    "F1": 0.5688
  },
  "EYES alteration 50% blend & NOSE alteration 100% blend Male": {
    "ΔFP": 0.0469,
    "ΔFN": -0.2907,
    "ΔAccuracy":0, 
     "ΔSP": 0.2805,
    "ΔEO": 0.2921,
    "Δauc": -0.0173,
    "All Accuracy": 0.7055,
    "Precision": 0.9203,
    "Recall": 0.4434,
    "F1": 0.5985
  },
    "EYES alteration 100% blend Male & NOSE alteration 100% blend Male & EYES alteration 50% blend Female": {
    "ΔFP": 0.0579,
    "ΔFN": -0.31865,
    "ΔAccuracy": -0.1223681,
    "ΔSP": 0.2981988,
    "ΔEO": 0.318652,
    "Δauc": -0.01515,
    "All Accuracy": 0.7095,
    "Precision": 0.91649,
    "Recall": 0.4545,
    "F1": 0.607
  },
  "EYES alteration 100% blend & NOSE alteration 100% blend": {
    "ΔFP": 0.041819,
    "ΔFN": -0.18011,
    "ΔAccuracy": -0.2061,
    "ΔSP": 0.202999,
    "ΔEO": 0.18011,
    "Δauc": -0.0601,
    "All Accuracy": 0.658,
    "Precision": 0.9090,
    "Recall": 0.3434,
    "F1": 0.4985
  }
}

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


delta_EO = [values["ΔEO"] for values in data2.values()]
delta_SP = [values["ΔSP"] for values in data2.values()]
all_accuracy = [values["All Accuracy"] for values in data2.values()]
labels = list(data2.keys())

fig = plt.figure(figsize=(30, 20))
ax = fig.add_subplot(111, projection='3d')

sc = ax.scatter(delta_EO, delta_SP, all_accuracy, c=range(len(delta_EO)), cmap='tab10', s=500)
for i in range(len(delta_EO)):
    ax.plot([delta_EO[i], delta_EO[i]], [delta_SP[i], delta_SP[i]], [0.62, all_accuracy[i]], color='gray', linestyle='--', alpha=0.5)

ax.set_xlabel('ΔEO')
ax.set_ylabel('ΔSP')
ax.set_zlabel('All Accuracy')
ax.set_title('3D Graph: ΔEO vs. ΔSP vs. All Accuracy')
ax.set_zlim(0.61, 0.72)
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=sc.to_rgba(i), markersize=10) for i in range(len(labels))]
ax.legend(handles, labels, loc='center left', bbox_to_anchor=(1.2, 0.8),prop={'size': 25})

plt.savefig('graph_3d_combo.png', bbox_inches='tight')
plt.show()
